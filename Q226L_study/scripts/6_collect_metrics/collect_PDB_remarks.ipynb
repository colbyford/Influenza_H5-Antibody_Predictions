# %% [markdown]
# # Collect Metrics from HADDOCK 3 Experiment Outputs
# ## PDB REMARK Metrics

# %%
import os
import pandas as pd
from biopandas.pdb import PandasPdb

# %%
## Function to return a dataframe of REMARK lines with energy scores from a PDB file
def get_remark_energy_df(pdb_path):
    ppdb = PandasPdb()
    ppdb.read_pdb(pdb_path)
    pdb_df = ppdb.df['OTHERS']
    ## get REMARK Lines
    remark_lines = pdb_df[pdb_df['record_name'] == 'REMARK']
    ## Get the energy scores
    energies_header = remark_lines[remark_lines['entry'].str.contains('total,')].iloc[0]['entry']
    energies_values = remark_lines[remark_lines['entry'].str.contains('energies: ')].iloc[0]['entry']
    energies_header = energies_header.replace(' ', '').split(',')
    energies_values = energies_values.split(': ')[-1].split(',')
    ## Make a dataframe
    energies_df = pd.DataFrame([energies_values], columns=energies_header)
    ## Get the desolvation energy and buried surface area
    de_value = remark_lines[remark_lines['entry'].str.contains('Desolvation energy:')].iloc[0]['entry']
    bsa_value = remark_lines[remark_lines['entry'].str.contains('buried surface area:')].iloc[0]['entry']
    de_value = de_value.split(': ')[-1].split(',')
    bsa_value = bsa_value.split(': ')[-1].split(',')
    ## Append to dataframe
    energies_df['desolv'] = de_value
    energies_df['bsa'] = bsa_value
    return energies_df

# %%
## Read in Experiments worksheet
experiments = pd.read_excel('../../Experiments.xlsx', sheet_name='Experiments')#.head(0)
## For testing...
# experiments = experiments.append({'experiment_id': 'TEST_5A3I'}, ignore_index=True)

# experiments.head()

# %%
## Create a dataframe to store the energy scores
haddock_energy_df = pd.DataFrame()

# %%
for index, experiment in experiments.iterrows():
    experiment_id = experiment['experiment_id']

    ## Check if the output/ directory exists
    # outputs_dir = f"../../data/experiments_test/{experiment_id}/output/10_caprieval"
    outputs_dir = f"../../data/results/{experiment_id}/output"
    if os.path.exists(outputs_dir):
        # print(f"Getting metrics for experiment: {experiment_id}")

        ## Read in the individual metrics file
        clustfcc_path = f"{outputs_dir}/09_clustfcc/clustfcc.tsv"
        ## Check if the FCC file exists:
        if os.path.exists(clustfcc_path):
            # print(f"\tClustFCC file exists...")
            clustfcc_df = pd.read_csv(clustfcc_path, sep='\t', comment='#')
            best_model = clustfcc_df.iloc[0]['model_name']

            for index, model in clustfcc_df.iterrows():
                model_name = model['model_name']
                haddock_score = model['score']

                ## Read in REMARK lines of PDB to get metrics
                pdb_path = f"{outputs_dir}/08_mdscoring/{model_name}"

                model_df = get_remark_energy_df(pdb_path)
                model_df['experiment_id'] = experiment_id
                model_df['model_name'] = model_name
                model_df['haddock_score'] = haddock_score
                model_df['best_model'] = model_name == best_model

                ## Append to the main dataframe
                # haddock_energy_df = haddock_energy_df.append(model_df, ignore_index=True)
                haddock_energy_df = pd.concat([haddock_energy_df, model_df], ignore_index=True)

# %%
## rename total energy columns
# haddock_energy_df = haddock_energy_df.rename(columns={'            total': 'total'})

# %%
haddock_energy_df.head()
# Out:
#       total bonds angles improper dihe        vdw       elec air cdih coup  \
# 0  -366.545     0      0        0    0   -71.0052    -295.54   0    0    0
# 1  -374.306     0      0        0    0   -57.8712   -316.435   0    0    0
# 2  -351.645     0      0        0    0   -62.1045    -289.54   0    0    0
# 3  -341.893     0      0        0    0   -59.1243   -282.768   0    0    0
# 4  -347.168     0      0        0    0   -59.7354   -287.432   0    0    0
#
#    ... vean dani xpcs  rg    desolv      bsa        experiment_id  \
# 0  ...    0    0    0   0  -13.1443  1913.26  FLD194__YP_308669.1
# 1  ...    0    0    0   0  -7.03946  1699.06  FLD194__YP_308669.1
# 2  ...    0    0    0   0  -6.02133  1765.15  FLD194__YP_308669.1
# 3  ...    0    0    0   0    -8.031  1714.84  FLD194__YP_308669.1
# 4  ...    0    0    0   0  -6.44042  1759.46  FLD194__YP_308669.1
#
#          model_name haddock_score  best_model
# 0   mdscoring_2.pdb       -143.26        True
# 1   mdscoring_8.pdb       -128.20       False
# 2  mdscoring_10.pdb       -126.03       False
# 3   mdscoring_5.pdb       -123.71       False
# 4   mdscoring_3.pdb       -123.66       False
#
# [5 rows x 21 columns]

# %%
## Reorder columns
# haddock_energy_df_subset = haddock_energy_df[['experiment_id', 'model_name', 'haddock_score', 'vdw', 'elec', 'desolv', 'air', 'bsa', 'total']]

## Save the dataframe to a file
haddock_energy_df.to_csv('full_metrics.csv', index=False)

# %%
meta_cols = ['experiment_id', 'model_name', 'best_model']
metric_cols = ['haddock_score', 'vdw', 'elec', 'total', 'desolv', 'bsa']
discard_cols = [col for col in haddock_energy_df.columns if col not in meta_cols + metric_cols]

# %%
## Fix metric columns to be float
for col in metric_cols:
    haddock_energy_df[col] = haddock_energy_df[col].astype(float)

# %%
## Get the metrics from the best PDB
best_df = haddock_energy_df[haddock_energy_df['best_model'] == True].drop(columns=discard_cols)

## add "_best" to the column names except for 'experiment_id' and model
best_df.columns = [f"{col}_best" if col in metric_cols else col for col in best_df.columns]

best_df
# Out:
#      total_best  vdw_best  elec_best  desolv_best  bsa_best  \
# 0      -366.545  -71.0052   -295.540   -13.144300   1913.26
# 10     -354.275  -73.2893   -280.986     3.944940   1774.51
# 20     -318.151 -115.6650   -202.486   -47.240200   2785.14
# 30     -273.023  -59.5087   -213.514    -6.449340   1774.16
# 40     -405.459  -83.3447   -322.115   -17.733300   2167.31
# 50     -452.712  -59.2069   -393.505    11.428100   1665.44
# 60     -385.602  -82.3200   -303.282    13.536200   2278.86
# 70     -527.470  -88.1391   -439.330   -34.840200   2509.71
# 80     -224.452  -99.4782   -124.974   -39.894900   2451.79
# 88     -362.397  -58.8937   -303.504     0.919882   1458.03
# 98     -688.549 -106.5390   -582.009   -32.329000   2870.92
# 108    -311.393  -75.9036   -235.490     9.281760   2275.66
# 118    -385.368  -70.4449   -314.924    -1.444750   2025.24
# 128    -404.372 -112.9210   -291.451   -13.123100   2599.54
# 138    -265.289  -71.5234   -193.765     1.816190   1946.33
# 148    -391.301  -99.0890   -292.212    -3.758760   2596.31
# 157    -378.851  -95.4539   -283.397    -1.521650   2112.19
# 166    -374.148  -91.0919   -283.056     2.324980   2566.78
# 176    -281.532  -65.3012   -216.230   -11.563800   1800.60
# 186    -235.202  -85.7513   -149.451    -9.861290   1980.97
# 195    -310.739  -69.7323   -241.006     0.419546   1616.80
# 205    -667.699  -96.4252   -571.274   -14.555500   3031.07
# 215    -575.433 -100.6280   -474.804    16.664300   2837.55
# 225    -364.762  -60.5096   -304.253     3.061560   1881.04
# 235    -434.638  -70.4085   -364.229   -18.438900   2331.09
# 245    -266.420  -67.9428   -198.477     1.162990   2035.28
# 255    -521.438  -92.3186   -429.119   -19.331700   2512.99
# 262    -509.612  -86.0117   -423.600    -5.703130   2466.96
# 272    -508.573  -80.5480   -428.025     1.942030   2215.61
# 282    -557.985  -87.7950   -470.190   -10.931500   2405.51
# 292    -529.390  -86.2174   -443.172    -3.919190   2206.90
# 302    -545.710  -77.0364   -468.673   -14.806100   2369.87
#
#                experiment_id       model_name  haddock_score_best  best_model
# 0        FLD194__YP_308669.1  mdscoring_2.pdb             -143.26        True
# 10         H5.3__YP_308669.1  mdscoring_1.pdb             -125.54        True
# 20         65C6__YP_308669.1  mdscoring_2.pdb             -203.40        True
# 30        100F4__YP_308669.1  mdscoring_2.pdb             -108.66        True
# 40         3C11__YP_308669.1  mdscoring_3.pdb             -165.50        True
# 50   AVFluIgG01__YP_308669.1  mdscoring_2.pdb             -126.48        True
# 60    FLD21.140__YP_308669.1  mdscoring_2.pdb             -129.44        True
# 70         H5M9__YP_308669.1  mdscoring_1.pdb             -210.85        True
# 80         13D4__YP_308669.1  mdscoring_3.pdb             -164.37        True
# 88   AVFluIgG03__YP_308669.1  mdscoring_4.pdb             -118.67        True
# 98         12H5__YP_308669.1  mdscoring_4.pdb             -255.27        True
# 108       FLD194__WYN03019.1  mdscoring_2.pdb             -113.72        True
# 118         H5.3__WYN03019.1  mdscoring_5.pdb             -134.87        True
# 128         65C6__WYN03019.1  mdscoring_9.pdb             -184.33        True
# 138        100F4__WYN03019.1  mdscoring_1.pdb             -108.46        True
# 148         3C11__WYN03019.1  mdscoring_2.pdb             -161.29        True
# 157   AVFluIgG01__WYN03019.1  mdscoring_2.pdb             -153.65        True
# 166    FLD21.140__WYN03019.1  mdscoring_8.pdb             -145.38        True
# 176         H5M9__WYN03019.1  mdscoring_4.pdb             -120.11        True
# 186         13D4__WYN03019.1  mdscoring_6.pdb             -125.50        True
# 195   AVFluIgG03__WYN03019.1  mdscoring_9.pdb             -117.51        True
# 205         12H5__WYN03019.1  mdscoring_1.pdb             -225.24        True
# 215       FLD194__AAT73273.1  mdscoring_2.pdb             -178.92        True
# 225         H5.3__AAT73273.1  mdscoring_8.pdb             -118.30        True
# 235         65C6__AAT73273.1  mdscoring_4.pdb             -161.69        True
# 245        100F4__AAT73273.1  mdscoring_8.pdb             -106.48        True
# 255         3C11__AAT73273.1  mdscoring_1.pdb             -197.47        True
# 262   AVFluIgG01__AAT73273.1  mdscoring_3.pdb             -176.43        True
# 272    FLD21.140__AAT73273.1  mdscoring_1.pdb             -164.21        True
# 282         13D4__AAT73273.1  mdscoring_1.pdb             -192.76        True
# 292   AVFluIgG03__AAT73273.1  mdscoring_3.pdb             -178.77        True
# 302         12H5__AAT73273.1  mdscoring_2.pdb             -185.58        True

# %%
## Summarize the results by experiment_id, summarizing the metrics
summary_df = haddock_energy_df.groupby(['experiment_id']).agg({'haddock_score': ['min', 'mean', 'max', 'std'],
                                                   'bsa': ['min', 'mean', 'max', 'std'],
                                                   'desolv': ['min', 'mean', 'max', 'std'],
                                                   'elec': ['min', 'mean', 'max', 'std'],
                                                   'total': ['min', 'mean', 'max', 'std'],
                                                   'vdw': ['min', 'mean', 'max', 'std']}).reset_index()

## Flatten the column names
summary_df.columns = ['experiment_id'] + ['_'.join(col).strip() for col in summary_df.columns.values if col[0] in metric_cols]

## Join the summary and best metrics
summary_df = summary_df.merge(best_df, on=['experiment_id'], how='left')

## Reorder columns starting with the meta columns and then alphabetically thereafter
summary_df = summary_df[meta_cols + sorted([col for col in summary_df.columns if col not in meta_cols])]

## Remove the 'best_pdb_flag' column
summary_df = summary_df.drop(columns=['best_model'])

# %%
summary_df
# Out:
#               experiment_id       model_name  bsa_best  bsa_max     bsa_mean  \
# 0         100F4__AAT73273.1  mdscoring_8.pdb   2035.28  2035.28  1869.221000
# 1         100F4__WYN03019.1  mdscoring_1.pdb   1946.33  1989.63  1835.670000
# 2        100F4__YP_308669.1  mdscoring_2.pdb   1774.16  1774.16  1631.400000
# 3          12H5__AAT73273.1  mdscoring_2.pdb   2369.87  2498.80  2324.539000
# 4          12H5__WYN03019.1  mdscoring_1.pdb   3031.07  3031.07  2531.798000
# 5         12H5__YP_308669.1  mdscoring_4.pdb   2870.92  2870.92  2702.682000
# 6          13D4__AAT73273.1  mdscoring_1.pdb   2405.51  2405.51  2245.043000
# 7          13D4__WYN03019.1  mdscoring_6.pdb   1980.97  2090.05  1845.553333
# 8         13D4__YP_308669.1  mdscoring_3.pdb   2451.79  2669.11  2371.036250
# 9          3C11__AAT73273.1  mdscoring_1.pdb   2512.99  2748.27  2567.878571
# 10         3C11__WYN03019.1  mdscoring_2.pdb   2596.31  2596.31  2435.750000
# 11        3C11__YP_308669.1  mdscoring_3.pdb   2167.31  2167.31  1983.353000
# 12         65C6__AAT73273.1  mdscoring_4.pdb   2331.09  2361.29  2249.729000
# 13         65C6__WYN03019.1  mdscoring_9.pdb   2599.54  2599.54  2291.653000
# 14        65C6__YP_308669.1  mdscoring_2.pdb   2785.14  2802.54  2664.824000
# 15   AVFluIgG01__AAT73273.1  mdscoring_3.pdb   2466.96  2466.96  2114.303000
# 16   AVFluIgG01__WYN03019.1  mdscoring_2.pdb   2112.19  2112.19  1957.155556
# 17  AVFluIgG01__YP_308669.1  mdscoring_2.pdb   1665.44  1665.44  1596.027000
# 18   AVFluIgG03__AAT73273.1  mdscoring_3.pdb   2206.90  2270.18  2105.869000
# 19   AVFluIgG03__WYN03019.1  mdscoring_9.pdb   1616.80  1668.66  1543.085000
# 20  AVFluIgG03__YP_308669.1  mdscoring_4.pdb   1458.03  1537.39  1460.770000
# 21       FLD194__AAT73273.1  mdscoring_2.pdb   2837.55  2837.55  2566.768000
# 22       FLD194__WYN03019.1  mdscoring_2.pdb   2275.66  2292.65  2181.773000
# 23      FLD194__YP_308669.1  mdscoring_2.pdb   1913.26  1913.26  1759.408000
# 24    FLD21.140__AAT73273.1  mdscoring_1.pdb   2215.61  2414.13  2154.069000
# 25    FLD21.140__WYN03019.1  mdscoring_8.pdb   2566.78  2566.78  2262.224000
# 26   FLD21.140__YP_308669.1  mdscoring_2.pdb   2278.86  2278.86  1991.536000
# 27         H5.3__AAT73273.1  mdscoring_8.pdb   1881.04  1986.29  1883.721000
# 28         H5.3__WYN03019.1  mdscoring_5.pdb   2025.24  2181.27  2029.937000
# 29        H5.3__YP_308669.1  mdscoring_1.pdb   1774.51  1774.51  1675.888000
# 30         H5M9__WYN03019.1  mdscoring_4.pdb   1800.60  1867.66  1667.421000
# 31        H5M9__YP_308669.1  mdscoring_1.pdb   2509.71  2557.58  2403.742000
#
#     bsa_min     bsa_std  desolv_best  desolv_max  desolv_mean  ...  \
# 0   1643.57  108.076808     1.162990   14.130600     2.438380  ...
# 1   1707.52   90.543020     1.816190    7.583350    -0.134731  ...
# 2   1482.17   95.539894    -6.449340    3.958520    -4.318197  ...
# 3   2160.74   95.482327   -14.806100  -12.241000   -16.212460  ...
# 4   2304.98  229.706702   -14.555500  -14.229400   -20.630880  ...
# 5   2472.69  122.676080   -32.329000  -19.063700   -32.036480  ...
# 6   2036.10  120.855786   -10.931500   -0.344272    -6.004612  ...
# 7   1614.26  155.266377    -9.861290    2.562390    -6.449170  ...
# 8   2271.23  136.094797   -39.894900  -26.445700   -33.311975  ...
# 9   2390.74  126.928566   -19.331700   -8.431620   -14.688360  ...
# 10  2304.92  106.303535    -3.758760    3.042970    -2.140974  ...
# 11  1774.76  116.475716   -17.733300  -15.510600   -21.205050  ...
# 12  1993.11  115.422573   -18.438900   -8.976030   -18.987943  ...
# 13  2085.90  139.663418   -13.123100   -5.974550   -10.865067  ...
# 14  2533.66  102.193562   -47.240200  -32.299200   -41.066670  ...
# 15  1676.08  230.278894    -5.703130    6.911090    -3.019525  ...
# 16  1680.99  131.422040    -1.521650    7.322200     2.963343  ...
# 17  1499.89   61.408963    11.428100   11.428100     4.136755  ...
# 18  1961.60  104.006660    -3.919190    6.300680    -1.755269  ...
# 19  1432.79   82.243774     0.419546    8.334160     2.782790  ...
# 20  1374.71   45.463605     0.919882    5.445120     0.617187  ...
# 21  2366.86  130.318211    16.664300   16.664300    12.153333  ...
# 22  2027.29   84.863461     9.281760   11.675500     8.617674  ...
# 23  1665.87   76.434925   -13.144300   -3.202110    -7.086761  ...
# 24  1958.03  148.687295     1.942030   12.615300     3.258138  ...
# 25  1995.62  199.851008     2.324980   13.373100     8.516990  ...
# 26  1769.87  157.167713    13.536200   18.422100     8.944259  ...
# 27  1817.47   48.738382     3.061560    6.691750     2.832245  ...
# 28  1911.33   89.399398    -1.444750    9.887610    -0.840091  ...
# 29  1598.50   70.621475     3.944940   10.159800     6.567551  ...
# 30  1529.85  100.235497   -11.563800   -3.019810    -8.346683  ...
# 31  2209.30  122.928266   -34.840200  -26.183800   -33.218410  ...
#
#     total_best  total_max  total_mean  total_min   total_std  vdw_best  \
# 0     -266.420   -156.120 -218.157100   -269.286   38.491213  -67.9428
# 1     -265.289   -173.680 -229.140900   -265.289   26.385022  -71.5234
# 2     -273.023   -151.218 -222.960000   -273.023   39.834203  -59.5087
# 3     -545.710   -466.177 -506.243900   -589.549   45.530418  -77.0364
# 4     -667.699   -350.468 -451.576300   -667.699   95.891683  -96.4252
# 5     -688.549   -378.319 -531.785600   -688.549  100.095637 -106.5390
# 6     -557.985   -420.521 -525.816600   -601.375   53.175592  -87.7950
# 7     -235.202   -149.766 -190.822333   -246.093   32.418921  -85.7513
# 8     -224.452   -182.342 -232.162375   -294.237   33.267166  -99.4782
# 9     -521.438   -434.989 -477.471286   -521.438   39.142421  -92.3186
# 10    -391.301   -307.780 -344.092333   -395.633   30.147999  -99.0890
# 11    -405.459   -333.000 -358.237000   -405.459   23.479441  -83.3447
# 12    -434.638   -270.114 -333.056000   -434.638   51.128944  -70.4085
# 13    -404.372   -235.858 -302.924400   -404.372   57.065193 -112.9210
# 14    -318.151   -216.225 -265.027400   -318.151   36.264248 -115.6650
# 15    -509.612   -300.295 -407.315900   -509.612   72.476302  -86.0117
# 16    -378.851   -210.121 -360.358111   -422.427   60.120970  -95.4539
# 17    -452.712   -295.286 -385.624600   -452.712   47.983069  -59.2069
# 18    -529.390   -401.950 -472.094200   -529.390   35.122339  -86.2174
# 19    -310.739   -194.376 -303.778800   -336.240   40.576639  -69.7323
# 20    -362.397   -287.109 -332.658200   -387.080   30.300355  -58.8937
# 21    -575.433   -404.098 -465.520500   -575.433   52.674851 -100.6280
# 22    -311.393   -238.032 -278.141400   -323.124   26.636945  -75.9036
# 23    -366.545   -275.027 -338.958300   -374.306   31.905051  -71.0052
# 24    -508.573   -361.922 -437.102200   -508.573   48.715199  -80.5480
# 25    -374.148   -303.194 -349.101300   -459.109   49.665471  -91.0919
# 26    -385.602   -254.632 -311.438300   -418.673   56.587840  -82.3200
# 27    -364.762   -249.121 -309.368300   -366.960   45.032333  -60.5096
# 28    -385.368   -262.475 -351.162200   -438.846   48.802265  -70.4449
# 29    -354.275   -272.247 -299.840800   -356.500   33.665888  -73.2893
# 30    -281.532   -188.844 -240.837900   -307.903   38.438986  -65.3012
# 31    -527.470   -383.282 -437.101600   -527.470   44.149348  -88.1391
#
#     vdw_max    vdw_mean   vdw_min    vdw_std
# 0  -56.3198  -64.217630  -67.9428   3.958831
# 1  -56.5829  -67.459020  -73.8372   5.598631
# 2  -42.0628  -55.057370  -61.5103   6.010659
# 3  -53.0692  -68.487220  -79.0584   7.648401
# 4  -58.6318  -75.191360  -96.4252  10.110915
# 5  -93.8748 -102.754430 -118.8080   8.562616
# 6  -60.7659  -77.585930  -87.7950   8.231218
# 7  -47.9538  -69.755544  -85.7513  11.947595
# 8  -75.9147  -87.758725 -100.7320   9.712107
# 9  -80.5852  -91.195271  -98.7223   5.570761
# 10 -82.9093  -92.810289 -107.6410   8.143316
# 11 -60.9814  -75.963440  -89.1382   8.546831
# 12 -70.4085  -78.229130  -84.6883   5.269138
# 13 -80.6763  -92.776570 -112.9210   9.251497
# 14 -92.9018 -106.773850 -119.1040  10.620569
# 15 -52.9758  -71.906700  -86.0117  10.795940
# 16 -58.3285  -77.030567  -95.4539   9.652295
# 17 -42.8436  -55.378340  -73.3376   8.791067
# 18 -62.6034  -76.335260  -87.7124   8.496385
# 19 -49.6582  -58.041630  -69.7323   6.995017
# 20 -44.3753  -52.038000  -65.3534   7.138542
# 21 -74.3221  -88.136720 -100.6280   9.179013
# 22 -63.5648  -72.235010  -77.9727   4.294205
# 23 -54.3213  -61.697500  -71.0052   4.790119
# 24 -55.1687  -74.767050  -83.9476   8.016252
# 25 -59.0620  -78.055050  -91.0919   9.022488
# 26 -65.4313  -75.732990  -82.3200   5.242510
# 27 -49.4743  -57.773120  -62.7279   4.701239
# 28 -54.9829  -63.199300  -70.4449   5.114334
# 29 -52.4595  -64.598240  -73.2893   6.634906
# 30 -54.9414  -63.048670  -73.1277   5.943744
# 31 -71.7421  -83.681310  -91.4265   6.349093
#
# [32 rows x 32 columns]

# %%
## Save the summary dataframe to a file
summary_df.to_csv('summary_metrics.csv', index=False)
