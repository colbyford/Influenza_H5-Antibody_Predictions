# %% [markdown]
# # Create HADDOCK 3 Experiments

# %%
import shutil, os, configparser
import pandas as pd

# %%
experiments = pd.read_excel('../../Experiments.xlsx', sheet_name='Experiments')#.head(3)
## Filter experiments to only incomplete ones
experiments = experiments[experiments['complete'] == False]

antibodies = pd.read_excel('../../Experiments.xlsx', sheet_name='Antibodies')
antigens = pd.read_excel('../../Experiments.xlsx', sheet_name='Antigens')

experiments#.head()
# Out:
#                experiment_id antibody_id  antigen_id  submitted  complete  \
# 0           H5.3__EPI2800361        H5.3  EPI2800361       True     False
# 5           H5.3__EPI1328383        H5.3  EPI1328383       True     False
# 108          65C6__EPI275862        65C6   EPI275862       True     False
# 154          100F4__EPI22627       100F4    EPI22627       True     False
# 644        FLD194__EPI359880      FLD194   EPI359880       True     False
# 695     AVFluIgG01__EPI25072  AVFluIgG01    EPI25072       True     False
# 747          H5.3__EPI533388        H5.3   EPI533388       True     False
# 1002         13D4__EPI235171        13D4   EPI235171       True     False
# 1004         H5.3__EPI359867        H5.3   EPI359867       True     False
# 1189        65C6__EPI1947325        65C6  EPI1947325       True     False
# 1269        H5.3__EPI1947325        H5.3  EPI1947325       True     False
# 1390         H5M9__EPI331854        H5M9   EPI331854       True     False
# 1670         13D4__EPI101843        13D4   EPI101843       True     False
# 1671          3C11__EPI97199        3C11    EPI97199       True     False
# 1789       100F4__EPI2017778       100F4  EPI2017778       True     False
# 1793        H5M9__EPI3358339        H5M9  EPI3358339      False     False
# 1794        3C11__EPI3358339        3C11  EPI3358339      False     False
# 1795        13D4__EPI3358339        13D4  EPI3358339      False     False
# 1796        65C6__EPI3358339        65C6  EPI3358339      False     False
# 1797   FLD21.140__EPI3358339   FLD21.140  EPI3358339      False     False
# 1798       100F4__EPI3358339       100F4  EPI3358339      False     False
# 1799  AVFluIgG01__EPI3358339  AVFluIgG01  EPI3358339      False     False
# 1800        H5.3__EPI3358339        H5.3  EPI3358339      False     False
# 1801        12H5__EPI3358339        12H5  EPI3358339      False     False
# 1802      FLD194__EPI3358339      FLD194  EPI3358339      False     False
# 1803  AVFluIgG03__EPI3358339  AVFluIgG03  EPI3358339      False     False
#
#      best_model_name  bsa_best  bsa_max  bsa_mean  bsa_min  ...  total_best  \
# 0                NaN       NaN      NaN       NaN      NaN  ...         NaN
# 5                NaN       NaN      NaN       NaN      NaN  ...         NaN
# 108              NaN       NaN      NaN       NaN      NaN  ...         NaN
# 154              NaN       NaN      NaN       NaN      NaN  ...         NaN
# 644              NaN       NaN      NaN       NaN      NaN  ...         NaN
# 695              NaN       NaN      NaN       NaN      NaN  ...         NaN
# 747              NaN       NaN      NaN       NaN      NaN  ...         NaN
# 1002             NaN       NaN      NaN       NaN      NaN  ...         NaN
# 1004             NaN       NaN      NaN       NaN      NaN  ...         NaN
# 1189             NaN       NaN      NaN       NaN      NaN  ...         NaN
# 1269             NaN       NaN      NaN       NaN      NaN  ...         NaN
# 1390             NaN       NaN      NaN       NaN      NaN  ...         NaN
# 1670             NaN       NaN      NaN       NaN      NaN  ...         NaN
# 1671             NaN       NaN      NaN       NaN      NaN  ...         NaN
# 1789             NaN       NaN      NaN       NaN      NaN  ...         NaN
# 1793             NaN       NaN      NaN       NaN      NaN  ...         NaN
# 1794             NaN       NaN      NaN       NaN      NaN  ...         NaN
# 1795             NaN       NaN      NaN       NaN      NaN  ...         NaN
# 1796             NaN       NaN      NaN       NaN      NaN  ...         NaN
# 1797             NaN       NaN      NaN       NaN      NaN  ...         NaN
# 1798             NaN       NaN      NaN       NaN      NaN  ...         NaN
# 1799             NaN       NaN      NaN       NaN      NaN  ...         NaN
# 1800             NaN       NaN      NaN       NaN      NaN  ...         NaN
# 1801             NaN       NaN      NaN       NaN      NaN  ...         NaN
# 1802             NaN       NaN      NaN       NaN      NaN  ...         NaN
# 1803             NaN       NaN      NaN       NaN      NaN  ...         NaN
#
#       total_max  total_mean  total_min  total_std  vdw_best  vdw_max  \
# 0           NaN         NaN        NaN        NaN       NaN      NaN
# 5           NaN         NaN        NaN        NaN       NaN      NaN
# 108         NaN         NaN        NaN        NaN       NaN      NaN
# 154         NaN         NaN        NaN        NaN       NaN      NaN
# 644         NaN         NaN        NaN        NaN       NaN      NaN
# 695         NaN         NaN        NaN        NaN       NaN      NaN
# 747         NaN         NaN        NaN        NaN       NaN      NaN
# 1002        NaN         NaN        NaN        NaN       NaN      NaN
# 1004        NaN         NaN        NaN        NaN       NaN      NaN
# 1189        NaN         NaN        NaN        NaN       NaN      NaN
# 1269        NaN         NaN        NaN        NaN       NaN      NaN
# 1390        NaN         NaN        NaN        NaN       NaN      NaN
# 1670        NaN         NaN        NaN        NaN       NaN      NaN
# 1671        NaN         NaN        NaN        NaN       NaN      NaN
# 1789        NaN         NaN        NaN        NaN       NaN      NaN
# 1793        NaN         NaN        NaN        NaN       NaN      NaN
# 1794        NaN         NaN        NaN        NaN       NaN      NaN
# 1795        NaN         NaN        NaN        NaN       NaN      NaN
# 1796        NaN         NaN        NaN        NaN       NaN      NaN
# 1797        NaN         NaN        NaN        NaN       NaN      NaN
# 1798        NaN         NaN        NaN        NaN       NaN      NaN
# 1799        NaN         NaN        NaN        NaN       NaN      NaN
# 1800        NaN         NaN        NaN        NaN       NaN      NaN
# 1801        NaN         NaN        NaN        NaN       NaN      NaN
# 1802        NaN         NaN        NaN        NaN       NaN      NaN
# 1803        NaN         NaN        NaN        NaN       NaN      NaN
#
#       vdw_mean  vdw_min  vdw_std
# 0          NaN      NaN      NaN
# 5          NaN      NaN      NaN
# 108        NaN      NaN      NaN
# 154        NaN      NaN      NaN
# 644        NaN      NaN      NaN
# 695        NaN      NaN      NaN
# 747        NaN      NaN      NaN
# 1002       NaN      NaN      NaN
# 1004       NaN      NaN      NaN
# 1189       NaN      NaN      NaN
# 1269       NaN      NaN      NaN
# 1390       NaN      NaN      NaN
# 1670       NaN      NaN      NaN
# 1671       NaN      NaN      NaN
# 1789       NaN      NaN      NaN
# 1793       NaN      NaN      NaN
# 1794       NaN      NaN      NaN
# 1795       NaN      NaN      NaN
# 1796       NaN      NaN      NaN
# 1797       NaN      NaN      NaN
# 1798       NaN      NaN      NaN
# 1799       NaN      NaN      NaN
# 1800       NaN      NaN      NaN
# 1801       NaN      NaN      NaN
# 1802       NaN      NaN      NaN
# 1803       NaN      NaN      NaN
#
# [26 rows x 36 columns]

# %% [markdown]
# ## AIR Restraints File Logic

# %%
## Define functions for creating ambiguous AIR files
def write_ambig_air_file(active1, passive1, active2, passive2, segid1='A', segid2='B', output_file="ambig.tbl"):
    with open(output_file, "w") as output_file:
        ## Convert residues to integers
        active1 = [int(x) for x in active1]
        passive1 = [int(x) for x in passive1]
        active2 = [int(x) for x in active2]
        passive2 = [int(x) for x in passive2]
        all1 = active1 + passive1
        all2 = active2 + passive2

        ## Write lines from the active1 list
        for resi1 in active1:
            output_file.write('assign (resi {:d} and segid {:s})'.format(resi1, segid1) + '\n')
            output_file.write('(\n')
            c = 0
            for resi2 in all2:
                output_file.write('       (resi {:d} and segid {:s})'.format(resi2, segid2) + '\n')
                c += 1
                if c != len(all2):
                    output_file.write('        or\n')
            output_file.write(') 2.0 2.0 0.0\n\n')

        ## Write lines from the active2 list
        for resi2 in active2:
            output_file.write('assign (resi {:d} and segid {:s})'.format(resi2, segid2) + '\n')
            output_file.write('(\n')
            c = 0
            for resi1 in all1:
                output_file.write('       (resi {:d} and segid {:s})'.format(resi1, segid1) + '\n')
                c += 1
                if c != len(all1):
                    output_file.write('        or\n')
            output_file.write(') 2.0 2.0 0.0\n\n')

    ## File will be closed automatically when exiting the 'with' block

# %% [markdown]
# ## Make Config Files

# %%
def create_config(
      antibody_pdb = 'data/TEST_ANTIBODY.pdb',
      antigen_pdb = 'data/TEST_ANTIGEN.pdb',
      # reference_pdb = 'data/TEST_MATCHED.pdb',
      ambig_fname = "data/ambig.tbl",
      # unambig_fname = "data/unambig.tbl",
      output_file = 'config.cfg'
                  ):
    
    config = configparser.ConfigParser()

    ## Read the configuration file
    config.read('antibody_antigen_template_custom.cfg')

    ## Update the configuration
    config['main'] = {'run_dir': '"./output"',
                      'mode': '"local"',
                      'ncores': 36,
                     #  'concat':  5,
                     #  'queue_limit': 100,
                      'molecules': [
                            antibody_pdb,
                            antigen_pdb
                            ]}
 
    ## Write the configuration to a file
    with open(output_file, 'w') as configfile:
        config.write(configfile)

    ## Replace specific lines in config file (HACKY FIX)
    with open(output_file, 'r') as configfile:
      cfgdata = configfile.read()
    cfgdata = cfgdata.replace('[main]', '## Antibody-Antigen Docking with HADDOCK3') \
                    .replace('[clustfcc_0]', '[clustfcc]') \
                    .replace('[clustfcc_1]', '[clustfcc]') \
                    .replace('[clustfcc_2]', '[clustfcc]') \
                    .replace('[seletopclusts_0]', '[seletopclusts]') \
                    .replace('[seletopclusts_1]', '[seletopclusts]')
                                                                                                         
    ## Write the file out again
    with open(output_file, 'w') as configfile:
      configfile.write(cfgdata)

# %% [markdown]
# ## Loop Through Each Experiment and Make its Directory and Files

# %%
for index, experiment in experiments.iterrows():
    experiment_id = experiment['experiment_id']
    print(f"Preparing experiment: {experiment_id}")

    ## Find corresponding rows in the antibody and antigen dataframes
    antibody = antibodies[antibodies['antibody_id'] == experiment['antibody_id']].iloc[0]
    antigen = antigens[antigens['antigen_id'] == experiment['antigen_id']].iloc[0]

    ## Make experiment folders
    print(f"\tMaking experiment folders...")
    experiment_path = f"../../data/experiments/{experiment_id}/"
    os.makedirs(experiment_path, exist_ok=True)

    ## Copy antibody and antigen PDB files to experiment folder
    print(f"\tCopying antibody and antigen PDB files to experiment folder...")
    antibody_pdb_path = f"../../{antibody['antibody_pdb_path_renumbered']}"
    antibody_pdb_filename = os.path.basename(antibody_pdb_path)
    antigen_pdb_path = f"../../{antigen['antigen_pdb_path_renumbered']}"
    antigen_pdb_filename = os.path.basename(antigen_pdb_path)

    shutil.copyfile(antibody_pdb_path, f"{experiment_path}{antibody_pdb_filename}")
    shutil.copyfile(antigen_pdb_path, f"{experiment_path}{antigen_pdb_filename}")

    ## Copy reference PDB file to experiment folder
    # reference_pdb_filename = '5a3i_chainsACD.pdb'
    # shutil.copyfile(reference_pdb_filename, f"{experiment_path}{reference_pdb_filename}")

    ## Generate AIR file for each experiment using active and passive residues
    active1 = antibody['antibody_active_residues'].replace('`','').split(',')
    passive1 = []
    active2 = antigen['antigen_active_residues'].replace('`','').split(',')
    passive2 = []
    candidate_path = f"../../data/experiments/{experiment_id}/"
    air_file_name = f"ambig.tbl"
    print(f"\tGenerating AIR file...")
    write_ambig_air_file(active1, passive1,
                         active2, passive2,
                         segid1='A', segid2='B',
                         output_file = f"{experiment_path}{air_file_name}")

    ## Genearate config file for each experiment
    print(f"\tGenerating config file...")
    create_config(
      antibody_pdb = antibody_pdb_filename,
      antigen_pdb = antigen_pdb_filename,
      # reference_pdb = reference_pdb_filename,
      ambig_fname = air_file_name,
      # unambig_fname = "data/unambig_TEST.tbl",
      output_file = f"{experiment_path}config.cfg")
    
    print(f'\tDone preparing the experiment files for {experiment_id}!')
# Out:
# Preparing experiment: H5.3__EPI2800361
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI2800361!
# Preparing experiment: H5.3__EPI1328383
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI1328383!
# Preparing experiment: 65C6__EPI275862
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI275862!
# Preparing experiment: 100F4__EPI22627
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI22627!
# Preparing experiment: FLD194__EPI359880
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI359880!
# Preparing experiment: AVFluIgG01__EPI25072
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI25072!
# Preparing experiment: H5.3__EPI533388
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI533388!
# Preparing experiment: 13D4__EPI235171
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI235171!
# Preparing experiment: H5.3__EPI359867
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI359867!
# Preparing experiment: 65C6__EPI1947325
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI1947325!
# Preparing experiment: H5.3__EPI1947325
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI1947325!
# Preparing experiment: H5M9__EPI331854
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI331854!
# Preparing experiment: 13D4__EPI101843
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI101843!
# Preparing experiment: 3C11__EPI97199
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI97199!
# Preparing experiment: 100F4__EPI2017778
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI2017778!
# Preparing experiment: H5M9__EPI3358339
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI3358339!
# Preparing experiment: 3C11__EPI3358339
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI3358339!
# Preparing experiment: 13D4__EPI3358339
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI3358339!
# Preparing experiment: 65C6__EPI3358339
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI3358339!
# Preparing experiment: FLD21.140__EPI3358339
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI3358339!
# Preparing experiment: 100F4__EPI3358339
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI3358339!
# Preparing experiment: AVFluIgG01__EPI3358339
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI3358339!
# Preparing experiment: H5.3__EPI3358339
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI3358339!
# Preparing experiment: 12H5__EPI3358339
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 12H5__EPI3358339!
# Preparing experiment: FLD194__EPI3358339
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI3358339!
# Preparing experiment: AVFluIgG03__EPI3358339
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI3358339!
