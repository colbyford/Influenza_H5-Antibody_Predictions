# %% [markdown]
# # Create HADDOCK 3 Experiments

# %%
import shutil, os, configparser
import pandas as pd

# %%
experiments = pd.read_excel('../../Experiments.xlsx', sheet_name='Experiments')#.head(3)
antibodies = pd.read_excel('../../Experiments.xlsx', sheet_name='Antibodies')
antigens = pd.read_excel('../../Experiments.xlsx', sheet_name='Antigens')

experiments.head()
# Out:
#            experiment_id antibody_id  antigen_id  submitted  \
# 0       H5.3__EPI2800361        H5.3  EPI2800361      False
# 1  AVFluIgG01__EPI454493  AVFluIgG01   EPI454493      False
# 2        13D4__EPI687187        13D4   EPI687187      False
# 3      FLD194__EPI340788      FLD194   EPI340788      False
# 4       13D4__EPI1158808        13D4  EPI1158808      False
#
#    haddock_best_cluster  haddock_best_pdb_path  haddock_Nstruc  \
# 0                   NaN                    NaN             NaN
# 1                   NaN                    NaN             NaN
# 2                   NaN                    NaN             NaN
# 3                   NaN                    NaN             NaN
# 4                   NaN                    NaN             NaN
#
#    haddock_Evdw_plus_0.1Eelec  haddock_Evdw_plus_0.1Eelec_sd  haddock_Evdw  \
# 0                         NaN                            NaN           NaN
# 1                         NaN                            NaN           NaN
# 2                         NaN                            NaN           NaN
# 3                         NaN                            NaN           NaN
# 4                         NaN                            NaN           NaN
#
#    ...  haddock_AIRviol  haddock_AIRviol_sd  haddock_dihedviol  \
# 0  ...              NaN                 NaN                NaN
# 1  ...              NaN                 NaN                NaN
# 2  ...              NaN                 NaN                NaN
# 3  ...              NaN                 NaN                NaN
# 4  ...              NaN                 NaN                NaN
#
#    haddock_dihedviol_sd  haddock_BSA  haddock_BSA_sd  haddock_score  \
# 0                   NaN          NaN             NaN            NaN
# 1                   NaN          NaN             NaN            NaN
# 2                   NaN          NaN             NaN            NaN
# 3                   NaN          NaN             NaN            NaN
# 4                   NaN          NaN             NaN            NaN
#
#    haddock_score_sd  haddock_prodigy_deltaG_kcalpermol  \
# 0               NaN                                NaN
# 1               NaN                                NaN
# 2               NaN                                NaN
# 3               NaN                                NaN
# 4               NaN                                NaN
#
#    haddock_prodigy_dissociation_constant_M
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# ## AIR Restraints File Logic

# %%
## Define functions for creating ambiguous AIR files
def write_ambig_air_file(active1, passive1, active2, passive2, segid1='A', segid2='B', output_file="ambig.tbl"):
    with open(output_file, "w") as output_file:
        ## Convert residues to integers
        active1 = [int(x) for x in active1]
        passive1 = [int(x) for x in passive1]
        active2 = [int(x) for x in active2]
        passive2 = [int(x) for x in passive2]
        all1 = active1 + passive1
        all2 = active2 + passive2

        ## Write lines from the active1 list
        for resi1 in active1:
            output_file.write('assign (resi {:d} and segid {:s})'.format(resi1, segid1) + '\n')
            output_file.write('(\n')
            c = 0
            for resi2 in all2:
                output_file.write('       (resi {:d} and segid {:s})'.format(resi2, segid2) + '\n')
                c += 1
                if c != len(all2):
                    output_file.write('        or\n')
            output_file.write(') 2.0 2.0 0.0\n\n')

        ## Write lines from the active2 list
        for resi2 in active2:
            output_file.write('assign (resi {:d} and segid {:s})'.format(resi2, segid2) + '\n')
            output_file.write('(\n')
            c = 0
            for resi1 in all1:
                output_file.write('       (resi {:d} and segid {:s})'.format(resi1, segid1) + '\n')
                c += 1
                if c != len(all1):
                    output_file.write('        or\n')
            output_file.write(') 2.0 2.0 0.0\n\n')

    ## File will be closed automatically when exiting the 'with' block

# %% [markdown]
# ## Make Config Files

# %%
def create_config(
      antibody_pdb = 'data/TEST_ANTIBODY.pdb',
      antigen_pdb = 'data/TEST_ANTIGEN.pdb',
      # reference_pdb = 'data/TEST_MATCHED.pdb',
      ambig_fname = "data/ambig.tbl",
      # unambig_fname = "data/unambig.tbl",
      output_file = 'config.cfg'
                  ):
    
    config = configparser.ConfigParser()

    ## Read the configuration file
    config.read('antibody_antigen_template_custom.cfg')

    ## Update the configuration
    config['main'] = {'run_dir': '"./output"',
                      'mode': '"local"',
                      'ncores': 36,
                     #  'concat':  5,
                     #  'queue_limit': 100,
                      'molecules': [
                            antibody_pdb,
                            antigen_pdb
                            ]}
 
    ## Write the configuration to a file
    with open(output_file, 'w') as configfile:
        config.write(configfile)

    ## Replace specific lines in config file (HACKY FIX)
    with open(output_file, 'r') as configfile:
      cfgdata = configfile.read()
    cfgdata = cfgdata.replace('[main]', '## Antibody-Antigen Docking with HADDOCK3') \
                    .replace('[clustfcc_0]', '[clustfcc]') \
                    .replace('[clustfcc_1]', '[clustfcc]') \
                    .replace('[clustfcc_2]', '[clustfcc]') \
                    .replace('[seletopclusts_0]', '[seletopclusts]') \
                    .replace('[seletopclusts_1]', '[seletopclusts]')
                                                                                                         
    ## Write the file out again
    with open(output_file, 'w') as configfile:
      configfile.write(cfgdata)

# %% [markdown]
# ## Loop Through Each Experiment and Make its Directory and Files

# %%
for index, experiment in experiments.iterrows():
    experiment_id = experiment['experiment_id']
    print(f"Preparing experiment: {experiment_id}")

    ## Find corresponding rows in the antibody and antigen dataframes
    antibody = antibodies[antibodies['antibody_id'] == experiment['antibody_id']].iloc[0]
    antigen = antigens[antigens['antigen_id'] == experiment['antigen_id']].iloc[0]

    ## Make experiment folders
    print(f"\tMaking experiment folders...")
    experiment_path = f"../../data/experiments/{experiment_id}/"
    os.makedirs(experiment_path, exist_ok=True)

    ## Copy antibody and antigen PDB files to experiment folder
    print(f"\tCopying antibody and antigen PDB files to experiment folder...")
    antibody_pdb_path = f"../../{antibody['antibody_pdb_path_renumbered']}"
    antibody_pdb_filename = os.path.basename(antibody_pdb_path)
    antigen_pdb_path = f"../../{antigen['antigen_pdb_path_renumbered']}"
    antigen_pdb_filename = os.path.basename(antigen_pdb_path)

    shutil.copyfile(antibody_pdb_path, f"{experiment_path}{antibody_pdb_filename}")
    shutil.copyfile(antigen_pdb_path, f"{experiment_path}{antigen_pdb_filename}")

    ## Copy reference PDB file to experiment folder
    # reference_pdb_filename = '5a3i_chainsACD.pdb'
    # shutil.copyfile(reference_pdb_filename, f"{experiment_path}{reference_pdb_filename}")

    ## Generate AIR file for each experiment using active and passive residues
    active1 = antibody['antibody_active_residues'].replace('`','').split(',')
    passive1 = []
    active2 = antigen['antigen_active_residues'].replace('`','').split(',')
    passive2 = []
    candidate_path = f"../../data/experiments/{experiment_id}/"
    air_file_name = f"ambig.tbl"
    print(f"\tGenerating AIR file...")
    write_ambig_air_file(active1, passive1,
                         active2, passive2,
                         segid1='A', segid2='B',
                         output_file = f"{experiment_path}{air_file_name}")

    ## Genearate config file for each experiment
    print(f"\tGenerating config file...")
    create_config(
      antibody_pdb = antibody_pdb_filename,
      antigen_pdb = antigen_pdb_filename,
      # reference_pdb = reference_pdb_filename,
      ambig_fname = air_file_name,
      # unambig_fname = "data/unambig_TEST.tbl",
      output_file = f"{experiment_path}config.cfg")
    
    print(f'\tDone preparing the experiment files for {experiment_id}!')
# Out:
# Preparing experiment: H5.3__EPI2800361
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI2800361!
# Preparing experiment: AVFluIgG01__EPI454493
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI454493!
# Preparing experiment: 13D4__EPI687187
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI687187!
# Preparing experiment: FLD194__EPI340788
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI340788!
# Preparing experiment: 13D4__EPI1158808
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI1158808!
# Preparing experiment: H5.3__EPI1328383
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI1328383!
# Preparing experiment: 12H5__EPI467792
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 12H5__EPI467792!
# Preparing experiment: 12H5__EPI355443
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 12H5__EPI355443!
# Preparing experiment: 3C11__EPI275862
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI275862!
# Preparing experiment: FLD21.140__EPI275758
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI275758!
# Preparing experiment: 13D4__EPI275790
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI275790!
# Preparing experiment: 100F4__EPI3158642
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI3158642!
# Preparing experiment: 3C11__EPI340399
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI340399!
# Preparing experiment: 3C11__EPI234494
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI234494!
# Preparing experiment: 13D4__EPI275974
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI275974!
# Preparing experiment: AVFluIgG01__EPI1381432
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI1381432!
# Preparing experiment: FLD194__EPI214889
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI214889!
# Preparing experiment: 3C11__EPI2580113
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI2580113!
# Preparing experiment: FLD194__EPI235171
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI235171!
# Preparing experiment: 65C6__EPI25011
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI25011!
# Preparing experiment: FLD194__EPI235072
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI235072!
# Preparing experiment: 3C11__EPI533388
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI533388!
# Preparing experiment: FLD194__EPI940674
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI940674!
# Preparing experiment: 3C11__EPI107843
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI107843!
# Preparing experiment: 65C6__EPI234497
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI234497!
# Preparing experiment: 65C6__EPI2467482
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI2467482!
# Preparing experiment: H5.3__EPI318210
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI318210!
# Preparing experiment: 12H5__EPI371190
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 12H5__EPI371190!
# Preparing experiment: AVFluIgG03__EPI359214
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI359214!
# Preparing experiment: H5.3__EPI101843
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI101843!
# Preparing experiment: 3C11__EPI2580054
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI2580054!
# Preparing experiment: H5.3__EPI2300436
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI2300436!
# Preparing experiment: H5.3__EPI234497
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI234497!
# Preparing experiment: AVFluIgG01__EPI1536787
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI1536787!
# Preparing experiment: FLD21.140__EPI226845
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI226845!
# Preparing experiment: H5M9__EPI168674
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI168674!
# Preparing experiment: FLD21.140__EPI356510
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI356510!
# Preparing experiment: 12H5__EPI259006
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 12H5__EPI259006!
# Preparing experiment: 100F4__EPI242227
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI242227!
# Preparing experiment: H5M9__EPI559078
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI559078!
# Preparing experiment: 65C6__EPI4801
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI4801!
# Preparing experiment: AVFluIgG03__EPI167665
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI167665!
# Preparing experiment: FLD194__EPI284432
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI284432!
# Preparing experiment: H5.3__EPI559078
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI559078!
# Preparing experiment: FLD21.140__EPI101843
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI101843!
# Preparing experiment: H5.3__EPI222476
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI222476!
# Preparing experiment: AVFluIgG01__EPI2856448
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI2856448!
# Preparing experiment: H5.3__EPI475563
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI475563!
# Preparing experiment: 65C6__EPI359214
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI359214!
# Preparing experiment: 12H5__EPI1552374
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 12H5__EPI1552374!
# Preparing experiment: 3C11__EPI359864
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI359864!
# Preparing experiment: 12H5__EPI1158808
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 12H5__EPI1158808!
# Preparing experiment: 3C11__EPI1947325
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI1947325!
# Preparing experiment: 65C6__EPI275974
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI275974!
# Preparing experiment: FLD194__EPI3178330
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI3178330!
# Preparing experiment: H5M9__EPI340796
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI340796!
# Preparing experiment: FLD194__EPI492324
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI492324!
# Preparing experiment: 12H5__EPI492324
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 12H5__EPI492324!
# Preparing experiment: 65C6__EPI275790
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI275790!
# Preparing experiment: AVFluIgG03__EPI492324
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI492324!
# Preparing experiment: FLD194__EPI475563
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI475563!
# Preparing experiment: 13D4__EPI2429052
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI2429052!
# Preparing experiment: AVFluIgG01__EPI1303228
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI1303228!
# Preparing experiment: AVFluIgG01__EPI940674
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI940674!
# Preparing experiment: FLD21.140__EPI340788
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI340788!
# Preparing experiment: 3C11__EPI597824
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI597824!
# Preparing experiment: FLD21.140__EPI235902
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI235902!
# Preparing experiment: 3C11__EPI109421
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI109421!
# Preparing experiment: 3C11__EPI533432
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI533432!
# Preparing experiment: H5.3__EPI9640
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI9640!
# Preparing experiment: H5M9__EPI3158642
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI3158642!
# Preparing experiment: 65C6__EPI600770
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI600770!
# Preparing experiment: H5M9__EPI167553
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI167553!
# Preparing experiment: 3C11__EPI221986
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI221986!
# Preparing experiment: H5M9__EPI2856448
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI2856448!
# Preparing experiment: AVFluIgG03__EPI275758
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI275758!
# Preparing experiment: AVFluIgG01__EPI3009059
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI3009059!
# Preparing experiment: FLD194__EPI2580115
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI2580115!
# Preparing experiment: AVFluIgG03__EPI1536787
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI1536787!
# Preparing experiment: H5M9__EPI1328383
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI1328383!
# Preparing experiment: FLD21.140__EPI222018
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI222018!
# Preparing experiment: 13D4__EPI167665
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI167665!
# Preparing experiment: 100F4__EPI283783
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI283783!
# Preparing experiment: 12H5__EPI235072
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 12H5__EPI235072!
# Preparing experiment: AVFluIgG01__EPI1989804
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI1989804!
# Preparing experiment: 100F4__EPI1990120
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI1990120!
# Preparing experiment: 13D4__EPI471131
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI471131!
# Preparing experiment: 65C6__EPI1694134
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI1694134!
# Preparing experiment: H5.3__EPI687187
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI687187!
# Preparing experiment: FLD21.140__EPI1887774
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI1887774!
# Preparing experiment: H5.3__EPI533432
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI533432!
# Preparing experiment: 100F4__EPI226841
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI226841!
# Preparing experiment: 3C11__EPI1989804
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI1989804!
# Preparing experiment: FLD194__EPI123402
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI123402!
# Preparing experiment: H5M9__EPI448231
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI448231!
# Preparing experiment: 100F4__EPI359882
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI359882!
# Preparing experiment: 100F4__EPI2574086
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI2574086!
# Preparing experiment: H5M9__EPI467792
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI467792!
# Preparing experiment: 13D4__EPI1887774
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI1887774!
# Preparing experiment: FLD194__EPI559098
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI559098!
# Preparing experiment: 65C6__EPI318210
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI318210!
# Preparing experiment: H5.3__EPI492324
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI492324!
# Preparing experiment: 65C6__EPI2856448
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI2856448!
# Preparing experiment: H5.3__EPI97199
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI97199!
# Preparing experiment: AVFluIgG03__EPI597820
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI597820!
# Preparing experiment: 65C6__EPI25072
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI25072!
# Preparing experiment: AVFluIgG01__EPI2584443
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI2584443!
# Preparing experiment: AVFluIgG01__EPI109421
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI109421!
# Preparing experiment: 65C6__EPI275862
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI275862!
# Preparing experiment: 100F4__EPI1552374
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI1552374!
# Preparing experiment: 65C6__EPI340399
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI340399!
# Preparing experiment: AVFluIgG03__EPI226845
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI226845!
# Preparing experiment: FLD21.140__EPI284432
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI284432!
# Preparing experiment: FLD21.140__EPI318210
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI318210!
# Preparing experiment: H5.3__EPI328886
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI328886!
# Preparing experiment: AVFluIgG01__EPI1947325
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI1947325!
# Preparing experiment: 100F4__EPI559109
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI559109!
# Preparing experiment: 65C6__EPI653115
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI653115!
# Preparing experiment: AVFluIgG03__EPI3178330
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI3178330!
# Preparing experiment: FLD194__EPI1990120
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI1990120!
# Preparing experiment: AVFluIgG03__EPI1156382
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI1156382!
# Preparing experiment: 3C11__EPI600770
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI600770!
# Preparing experiment: H5M9__EPI2580134
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI2580134!
# Preparing experiment: 100F4__EPI559078
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI559078!
# Preparing experiment: H5.3__EPI257054
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI257054!
# Preparing experiment: 12H5__EPI25011
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 12H5__EPI25011!
# Preparing experiment: H5.3__EPI275878
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI275878!
# Preparing experiment: H5M9__EPI398581
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI398581!
# Preparing experiment: AVFluIgG03__EPI243001
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI243001!
# Preparing experiment: 3C11__EPI2580115
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI2580115!
# Preparing experiment: 100F4__EPI239055
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI239055!
# Preparing experiment: FLD194__EPI454493
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI454493!
# Preparing experiment: H5.3__EPI355443
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI355443!
# Preparing experiment: FLD21.140__EPI116497
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI116497!
# Preparing experiment: 100F4__EPI167553
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI167553!
# Preparing experiment: FLD21.140__EPI226841
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI226841!
# Preparing experiment: FLD194__EPI275822
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI275822!
# Preparing experiment: AVFluIgG03__EPI356510
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI356510!
# Preparing experiment: 65C6__EPI123402
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI123402!
# Preparing experiment: AVFluIgG01__EPI600770
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI600770!
# Preparing experiment: 3C11__EPI275758
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI275758!
# Preparing experiment: AVFluIgG01__EPI2419700
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI2419700!
# Preparing experiment: 65C6__EPI2573872
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI2573872!
# Preparing experiment: 100F4__EPI2580066
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI2580066!
# Preparing experiment: 3C11__EPI168674
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI168674!
# Preparing experiment: AVFluIgG03__EPI340399
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI340399!
# Preparing experiment: FLD21.140__EPI2017747
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI2017747!
# Preparing experiment: FLD21.140__EPI369182
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI369182!
# Preparing experiment: AVFluIgG01__EPI2580084
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI2580084!
# Preparing experiment: H5M9__EPI1650
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI1650!
# Preparing experiment: 65C6__EPI167553
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI167553!
# Preparing experiment: 65C6__EPI533432
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI533432!
# Preparing experiment: AVFluIgG03__EPI371190
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI371190!
# Preparing experiment: H5.3__EPI275974
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI275974!
# Preparing experiment: 100F4__EPI22627
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI22627!
# Preparing experiment: 100F4__EPI4801
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI4801!
# Preparing experiment: 3C11__EPI275782
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI275782!
# Preparing experiment: FLD194__EPI328886
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI328886!
# Preparing experiment: H5M9__EPI533427
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI533427!
# Preparing experiment: H5M9__EPI4801
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI4801!
# Preparing experiment: AVFluIgG03__EPI341364
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI341364!
# Preparing experiment: AVFluIgG01__EPI2300436
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI2300436!
# Preparing experiment: FLD194__EPI257053
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI257053!
# Preparing experiment: AVFluIgG03__EPI254385
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI254385!
# Preparing experiment: FLD21.140__EPI471131
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI471131!
# Preparing experiment: AVFluIgG01__EPI475563
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI475563!
# Preparing experiment: AVFluIgG03__EPI275878
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI275878!
# Preparing experiment: 65C6__EPI3158642
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI3158642!
# Preparing experiment: AVFluIgG01__EPI9640
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI9640!
# Preparing experiment: FLD21.140__EPI107843
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI107843!
# Preparing experiment: AVFluIgG03__EPI168674
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI168674!
# Preparing experiment: FLD194__EPI226839
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI226839!
# Preparing experiment: H5M9__EPI3178330
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI3178330!
# Preparing experiment: AVFluIgG03__EPI1517056
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI1517056!
# Preparing experiment: 3C11__EPI1517056
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI1517056!
# Preparing experiment: AVFluIgG01__EPI3178330
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI3178330!
# Preparing experiment: H5M9__EPI559109
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI559109!
# Preparing experiment: 65C6__EPI492324
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI492324!
# Preparing experiment: 65C6__EPI2116742
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI2116742!
# Preparing experiment: 3C11__EPI3178330
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI3178330!
# Preparing experiment: 13D4__EPI2580084
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI2580084!
# Preparing experiment: 12H5__EPI808932
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 12H5__EPI808932!
# Preparing experiment: 65C6__EPI214889
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI214889!
# Preparing experiment: FLD194__EPI107813
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI107813!
# Preparing experiment: H5.3__EPI235902
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI235902!
# Preparing experiment: AVFluIgG01__EPI257058
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI257058!
# Preparing experiment: FLD21.140__EPI275822
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI275822!
# Preparing experiment: H5.3__EPI2017778
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI2017778!
# Preparing experiment: AVFluIgG01__EPI22627
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI22627!
# Preparing experiment: 13D4__EPI168674
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI168674!
# Preparing experiment: H5M9__EPI537677
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI537677!
# Preparing experiment: 12H5__EPI234497
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 12H5__EPI234497!
# Preparing experiment: FLD21.140__EPI454493
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI454493!
# Preparing experiment: H5.3__EPI2580066
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI2580066!
# Preparing experiment: 13D4__EPI1650
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI1650!
# Preparing experiment: FLD21.140__EPI559109
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# ...
# Preparing experiment: AVFluIgG01__EPI321328
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI321328!
# Preparing experiment: 12H5__EPI2580092
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 12H5__EPI2580092!
# Preparing experiment: 65C6__EPI21066
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI21066!
# Preparing experiment: 12H5__EPI21062
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 12H5__EPI21062!
# Preparing experiment: 100F4__EPI275990
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI275990!
# Preparing experiment: 13D4__EPI226839
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI226839!
# Preparing experiment: AVFluIgG01__EPI2035782
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI2035782!
# Preparing experiment: AVFluIgG01__EPI359880
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI359880!
# Preparing experiment: FLD194__EPI533432
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI533432!
# Preparing experiment: 13D4__EPI764389
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI764389!
# Preparing experiment: FLD194__EPI359882
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI359882!
# Preparing experiment: FLD21.140__EPI2198548
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI2198548!
# Preparing experiment: H5M9__EPI116497
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI116497!
# Preparing experiment: FLD194__EPI839728
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI839728!
# Preparing experiment: 3C11__EPI420386
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI420386!
# Preparing experiment: 13D4__EPI226845
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI226845!
# Preparing experiment: 12H5__EPI340788
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 12H5__EPI340788!
# Preparing experiment: H5.3__EPI21062
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI21062!
# Preparing experiment: 3C11__EPI257053
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI257053!
# Preparing experiment: AVFluIgG01__EPI2580134
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI2580134!
# Preparing experiment: AVFluIgG03__EPI2580113
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI2580113!
# Preparing experiment: H5.3__EPI1381432
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI1381432!
# Preparing experiment: H5M9__EPI2580054
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI2580054!
# Preparing experiment: 3C11__EPI559109
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI559109!
# Preparing experiment: AVFluIgG03__EPI275862
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI275862!
# Preparing experiment: 13D4__EPI2800361
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI2800361!
# Preparing experiment: 13D4__EPI355443
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI355443!
# Preparing experiment: 65C6__EPI1156382
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI1156382!
# Preparing experiment: 100F4__EPI2580084
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI2580084!
# Preparing experiment: H5.3__EPI259006
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI259006!
# Preparing experiment: 100F4__EPI1887774
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI1887774!
# Preparing experiment: FLD194__EPI589108
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI589108!
# Preparing experiment: H5.3__EPI2035782
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI2035782!
# Preparing experiment: AVFluIgG01__EPI235072
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI235072!
# Preparing experiment: FLD21.140__EPI222476
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI222476!
# Preparing experiment: H5.3__EPI593757
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI593757!
# Preparing experiment: 3C11__EPI2580084
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI2580084!
# Preparing experiment: 13D4__EPI21066
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI21066!
# Preparing experiment: FLD21.140__EPI2437377
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI2437377!
# Preparing experiment: AVFluIgG03__EPI559098
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI559098!
# Preparing experiment: 65C6__EPI283783
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI283783!
# Preparing experiment: 100F4__EPI340788
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI340788!
# Preparing experiment: AVFluIgG03__EPI123402
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI123402!
# Preparing experiment: 100F4__EPI2584443
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI2584443!
# Preparing experiment: 65C6__EPI221986
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 65C6__EPI221986!
# Preparing experiment: FLD21.140__EPI226839
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI226839!
# Preparing experiment: 13D4__EPI25076
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI25076!
# Preparing experiment: AVFluIgG01__EPI101477
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI101477!
# Preparing experiment: AVFluIgG03__EPI537677
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG03__EPI537677!
# Preparing experiment: FLD21.140__EPI9640
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI9640!
# Preparing experiment: 3C11__EPI340796
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI340796!
# Preparing experiment: FLD21.140__EPI239055
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI239055!
# Preparing experiment: 13D4__EPI2573872
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI2573872!
# Preparing experiment: 3C11__EPI398581
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI398581!
# Preparing experiment: AVFluIgG01__EPI2580113
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for AVFluIgG01__EPI2580113!
# Preparing experiment: 3C11__EPI21066
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 3C11__EPI21066!
# Preparing experiment: FLD21.140__EPI2574086
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD21.140__EPI2574086!
# Preparing experiment: 12H5__EPI2580187
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 12H5__EPI2580187!
# Preparing experiment: H5.3__EPI287236
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5.3__EPI287236!
# Preparing experiment: H5M9__EPI2429052
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI2429052!
# Preparing experiment: 100F4__EPI257054
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI257054!
# Preparing experiment: 100F4__EPI2017778
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 100F4__EPI2017778!
# Preparing experiment: 13D4__EPI107813
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for 13D4__EPI107813!
# Preparing experiment: H5M9__EPI600770
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for H5M9__EPI600770!
# Preparing experiment: FLD194__EPI808932
# 	Making experiment folders...
# 	Copying antibody and antigen PDB files to experiment folder...
# 	Generating AIR file...
# 	Generating config file...
# 	Done preparing the experiment files for FLD194__EPI808932!
