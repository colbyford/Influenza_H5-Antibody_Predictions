# %% [markdown]
# # Check HADDOCK Experiment Status
# (To be run after pulling experiments from the HPC environment.)

# %%
import os
import pandas as pd

# %%
## Load in Experiments Excel file
experiments = pd.read_excel('../../Experiments.xlsx', sheet_name='Experiments')

experiments.head()
# Out:
#            experiment_id antibody_id  antigen_id  submitted  complete  model  \
# 0       H5.3__EPI2800361        H5.3  EPI2800361       True     False    NaN
# 1  AVFluIgG01__EPI454493  AVFluIgG01   EPI454493       True     False    NaN
# 2        13D4__EPI687187        13D4   EPI687187       True     False    NaN
# 3      FLD194__EPI340788      FLD194   EPI340788       True     False    NaN
# 4       13D4__EPI1158808        13D4  EPI1158808       True     False    NaN
#
#    caprieval_rank  air_best  air_mean  air_min  ...  score_min  score_std  \
# 0             NaN       NaN       NaN      NaN  ...        NaN        NaN
# 1             NaN       NaN       NaN      NaN  ...        NaN        NaN
# 2             NaN       NaN       NaN      NaN  ...        NaN        NaN
# 3             NaN       NaN       NaN      NaN  ...        NaN        NaN
# 4             NaN       NaN       NaN      NaN  ...        NaN        NaN
#
#    total_best  total_mean  total_min  total_std  vdw_best  vdw_mean  vdw_min  \
# 0         NaN         NaN        NaN        NaN       NaN       NaN      NaN
# 1         NaN         NaN        NaN        NaN       NaN       NaN      NaN
# 2         NaN         NaN        NaN        NaN       NaN       NaN      NaN
# 3         NaN         NaN        NaN        NaN       NaN       NaN      NaN
# 4         NaN         NaN        NaN        NaN       NaN       NaN      NaN
#
#    vdw_std
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
# [5 rows x 53 columns]

# %%
for index, experiment in experiments.iterrows():
    experiment_id = experiment['experiment_id']
    output_file_path = f'../../data/results/{experiment_id}/output/10_caprieval/capri_clt.tsv'

    ## Check if the file exists
    if not os.path.exists(output_file_path):
        experiments.at[index, 'complete'] = False
        continue
    else:
        experiments.at[index, 'complete'] = True

# %%
experiments['complete'].value_counts(dropna=False).plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='complete'>

# %%
## List of experiments that are complete
experiments[['experiment_id', 'complete']][experiments['complete'] == True]
# Out:
#             experiment_id complete
# 51       12H5__EPI1158808     True
# 513  FLD21.140__EPI355443     True
